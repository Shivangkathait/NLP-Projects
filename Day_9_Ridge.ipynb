# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_features=1, noise=5, n_samples=10000)
import matplotlib.pyplot as plt
plt.scatter(x,y,s=2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
from sklearn.linear_model import Ridge
reg = Ridge()
reg.fit(X_train,y_train)
# Out:
# Ridge()

# %%
reg.predict(X_test)
# Out:
# array([-76.94177871,  -4.28634523,  13.75429198, ...,  45.7169627 ,
#         58.94785126,  52.88614721], shape=(2000,))

# %%
reg.score(X_test, y_test)
# Out:
# 0.980629574880732

# %%
reg.coef_
# Out:
# array([34.79325858])

# %%
reg.intercept_
# Out:
# np.float64(0.07695872436558826)

# %%
y_pred = reg.predict(x)

# %%
plt.scatter(x,y,label='Actual',s=2)
plt.scatter(x,y_pred,label='Predicted',s=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=100)
reg.fit(X_train,y_train)
reg.score(X_test, y_test)
# Out:
# 0.9805450650910698

# %%
y_pred = reg.predict(x)

# %%
plt.scatter(x,y,label='Actual',s=2)
plt.scatter(x,y_pred,label='Predicted',s=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
reg.coef_
# Out:
# array([34.36695521])

# %%
reg = Ridge(alpha=100000)
reg.fit(X_train,y_train)
reg.score(X_test, y_test)
# Out:
# 0.13992859819746672

# %%
y_pred = reg.predict(x)

# %%
plt.scatter(x,y,label='Actual',s=2)
plt.scatter(x,y_pred,label='Predicted',s=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
reg.coef_
# Out:
# array([2.57163456])

# %%
reg = Ridge(alpha=10000000)
reg.fit(X_train,y_train)
reg.score(X_test, y_test)
# Out:
# 0.0015334815272631808

# %%
y_pred = reg.predict(x)
plt.scatter(x,y,label='Actual',s=2)
plt.scatter(x,y_pred,label='Predicted',s=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
reg.coef_
# Out:
# array([0.02774637])
