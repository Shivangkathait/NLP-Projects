# %% [markdown]
# ## Tokenization

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
a = "Hello and welcome friends to NLP workshop. My name is shridhar mankar. I will be teaching you NLP from scratch"

# %%
A = word_tokenize(a)
A
# Out:
# ['Hello',
#  'and',
#  'welcome',
#  'friends',
#  'to',
#  'NLP',
#  'workshop',
#  '.',
#  'My',
#  'name',
#  'is',
#  'shridhar',
#  'mankar',
#  '.',
#  'I',
#  'will',
#  'be',
#  'teaching',
#  'you',
#  'NLP',
#  'from',
#  'scratch']

# %%
S = sent_tokenize(a)
S
# Out:
# ['Hello and welcome friends to NLP workshop.',
#  'My name is shridhar mankar.',
#  'I will be teaching you NLP from scratch']

# %% [markdown]
# ## Type/Length/Frequency

# %%
type(A),len(A)
# Out:
# (list, 22)

# %%
from nltk.probability import FreqDist
frequency = FreqDist()

# %%
for i in A:
 frequency[i] = frequency[i]+1

frequency
# Out:
# FreqDist({'NLP': 2, '.': 2, 'Hello': 1, 'and': 1, 'welcome': 1, 'friends': 1, 'to': 1, 'workshop': 1, 'My': 1, 'name': 1, ...})

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem('Making')
# Out:
# 'make'

# %%
for i in A:
    print(pst.stem(i))
# Out:
# hello
# and
# welcom
# friend
# to
# nlp
# workshop
# .
# my
# name
# is
# shridhar
# mankar
# .
# i
# will
# be
# teach
# you
# nlp
# from
# scratch

# %%
print(pst.stem('universal'))
print(pst.stem('universe'))
print(pst.stem('university'))
# Out:
# univers
# univers
# univers

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
# nltk.download('omw-1.4') ## multi lingual wordmapping
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('trouble') ## lemmatizer
# Out:
# 'trouble'

# %%
pst.stem('trouble') ## Stemming
# Out:
# 'troubl'

# %%
for i in A:
    print(lemmatizer.lemmatize(i))
# Out:
# Hello
# and
# welcome
# friend
# to
# NLP
# workshop
# .
# My
# name
# is
# shridhar
# mankar
# .
# I
# will
# be
# teaching
# you
# NLP
# from
# scratch

# %%
print(lemmatizer.lemmatize('alumnus'))
print(lemmatizer.lemmatize('alumni'))
print(lemmatizer.lemmatize('universe'))
print(lemmatizer.lemmatize('university'))
# Out:
# alumnus
# alumnus
# universe
# university

# %% [markdown]
# ## post_tag

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
for i in A:
 print(nltk.pos_tag([i]))
# Out:
# [('Hello', 'NN')]
# [('and', 'CC')]
# [('welcome', 'NN')]
# [('friends', 'NNS')]
# [('to', 'TO')]
# [('NLP', 'NN')]
# [('workshop', 'NN')]
# [('.', '.')]
# [('My', 'PRP$')]
# [('name', 'NN')]
# [('is', 'VBZ')]
# [('shridhar', 'NN')]
# [('mankar', 'NN')]
# [('.', '.')]
# [('I', 'PRP')]
# [('will', 'MD')]
# [('be', 'VB')]
# [('teaching', 'VBG')]
# [('you', 'PRP')]
# [('NLP', 'NN')]
# [('from', 'IN')]
# [('scratch', 'NN')]

# %% [markdown]
# ## Name Entity Recognition

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
text= '''Harry Lives in New York'''
words= word_tokenize(text)
postags=pos_tag(words)

# %%
tree = nltk.ne_chunk(postags)
print(tree)
# Out:
# (S (PERSON Harry/NNP) Lives/VBZ in/IN (GPE New/NNP York/NNP))

# %%
text= 'John wants a new Samsung device from Pune'
words= word_tokenize(text)
postags=pos_tag(words)

tree = nltk.ne_chunk(postags)
print(tree)
# Out:
# (S
#   (PERSON John/NNP)
#   wants/VBZ
#   a/DT
#   new/JJ
#   (ORGANIZATION Samsung/NNP)
#   device/NN
#   from/IN
#   (GPE Pune/NNP))

# %% [markdown]
# ## Stopwords

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
msg = "My name is Amit mankar, I love making videos and watching kdrama. My speciality is making things easy"

words = word_tokenize(msg)

filtered_sentence = []

for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)

print(words)
print(filtered_sentence)
# Out:
# ['My', 'name', 'is', 'Amit', 'mankar', ',', 'I', 'love', 'making', 'videos', 'and', 'watching', 'kdrama', '.', 'My', 'speciality', 'is', 'making', 'things', 'easy']
# ['My', 'name', 'Amit', 'mankar', ',', 'I', 'love', 'making', 'videos', 'watching', 'kdrama', '.', 'My', 'speciality', 'making', 'things', 'easy']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
msg = "My name my is shridhar mankar, I love making videos and watching kdrama. My speciality is making things easy"

words = word_tokenize(msg)

filtered_sentence = []

for w in words:
    if w.lower() not in stop_words:
        filtered_sentence.append(w)

print(words)
print(filtered_sentence)
# Out:
# ['My', 'name', 'my', 'is', 'shridhar', 'mankar', ',', 'I', 'love', 'making', 'videos', 'and', 'watching', 'kdrama', '.', 'My', 'speciality', 'is', 'making', 'things', 'easy']
# ['name', 'shridhar', 'mankar', ',', 'love', 'making', 'videos', 'watching', 'kdrama', '.', 'speciality', 'making', 'things', 'easy']
